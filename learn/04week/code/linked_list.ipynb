# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None
        self.prev = None

# %%
node1 = Node('node1')

# %%
node2 = Node('node2')

# %%
node3 = Node('node3')
